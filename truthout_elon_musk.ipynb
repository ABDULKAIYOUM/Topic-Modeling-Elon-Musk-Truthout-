# %% [markdown]
# # Web Scrapping

# %%
# Require Libraries
import requests
from bs4 import BeautifulSoup
import time
import csv
import re

# Browser request to avoid being blocked
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
}


# Function to extract article headline, author, date, and cleaned content from a single article URL

def extract_article_content_single_paragraph(url):
    try:
        response = requests.get(url, headers=HEADERS)
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract headline
        title_tag = soup.find("h1", class_="ar__ti")
        headline = title_tag.get_text(strip=True) if title_tag else "No headline"

        # Extract author
        #author_tag = soup.find("dl", class_="byline list-inline font-sans d-inline mt-2 mb-0 black-70")
        #author = author_tag.get_text(strip=True) if author_tag else "No author"

        # Extract publication date
        date_tag = soup.find("time", class_="published")
        publication_date = date_tag.get_text(strip=True) if date_tag else "No publication date"

        # Extract article paragraphs
        paragraphs = []
        for tag in soup.find_all(True):
            if tag.name == "div" and tag.get("class") == ["truth-post-content-after"]:
                break
            if tag.name == "p":
                text = tag.get_text(separator=' ', strip=True)
                if text:
                    paragraphs.append(text)

        # Clean the text
        raw_text = ' '.join(paragraphs)
        cleaned_text = re.sub(r'\[.*?\]', '', raw_text)  # Remove [image or embed]
        cleaned_text = re.sub(r'http\S+', '', cleaned_text)  # Remove URLs
        cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()  # Normalize whitespace

        return {
            "headline": headline,
            #"author": author,
            "publication_date": publication_date,
            "link": url,
            "content": cleaned_text
        }

    except Exception as e:
        return {"error": str(e), "link": url}


# Function to collect all article links from the Elon Musk topic pages

def get_all_article_links():
    all_links = []
    current_page = 1
    while True:
        url = f"https://truthout.org/topics/elon-musk/page/{current_page}/"
        response = requests.get(url, headers=HEADERS)
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Stop if we reach a "Page not found"
        if soup.title and "Page not found" in soup.title.text:
            break
        
        # Find all article links on the current page
        article_blocks = soup.find_all("h2", class_="ar-list__ti mb-3 mb-md-2")
        links = [block.find("a")["href"] for block in article_blocks if block.find("a")]

        if not links:
            break

        all_links.extend(links)
        current_page += 1
        time.sleep(1) # polite delay

    return all_links

# Get article links
article_links = get_all_article_links()

# Save to CSV files
with open("elon_musk_truthout_corpus.csv", "w", encoding="utf-8") as content_file, \
     open("elon_musk_truthout_metadata.csv", "w", encoding="utf-8", newline='') as metadata_file:
    
     # Write corpus header
    content_file.write("Article\n")
    
    csv_writer = csv.writer(metadata_file)
    csv_writer.writerow(["Headline", "Publication Date", "Link"])

    for i, link in enumerate(article_links, 1):
        data = extract_article_content_single_paragraph(link)
        if "error" in data:
            print(f"Error in Article {i}: {data['error']}")
            continue

        print(f"Article {i}: {data['headline']}")

        # Write corpus
        content_file.write(f"{data['content']}\n")

        # Write metadata
        csv_writer.writerow([data['headline'], data['publication_date'], data['link']])

        time.sleep(1.5) # Delay to avoid overloading the server
# Out:
# Article 1: Former SSA Chief: “Elon Musk Is the Biggest Fraud, Not Social Security”
# Article 2: Trump Admin Wields Foreign Policy Apparatus to Advance Musk’s Business Interests
# Article 3: Trump’s Censorship Campaign Draws on Decades of Infrastructure Built by Big Tech
# Article 4: This Musk Adviser and DOGE Employee May Be Violating Ethics Rules, Experts Say
# Article 5: Trump Is Bending the Refugee Program to Fit His White Nationalist Agenda
# Article 6: Judge Blocks Trump-Musk’s “Unconstitutional Dismantling” of Federal Government
# Article 7: Corporate-Led Attack on Free Speech in Texas Meets Bipartisan Resistance
# Article 8: Trump Officials Pressure Nations to Approve Musk’s Starlink During Tariff Talks
# Article 9: Amid Near-Total Asylum Ban, Trump Welcomes White South Africans
# Article 10: Living Holders of Millions of Social Security Numbers Have Been Marked as Dead
# Article 11: Alliance Between Far Right and Silicon Valley Gives Rise to “End Times Fascism”
# Article 12: Trump and Musk Are Trying to Dismantle Social Security From the Inside
# Article 13: Trump’s Border Czar Threatens Governor With Arrest Over Routine Legal Guidance
# Article 14: Tesla Takedown Protesters Are Hitting Musk Where It Hurts: His Bottom Line
# Article 15: Is the DOGE Playbook Going Global?
# Article 16: Report: 2 DOGE Staffers Have Access to Network Holding US Nuclear Secrets
# Article 17: Musk Aims to Expand Polluting Data Center Near Historically Black Neighborhoods
# Article 18: By Refusing to Surrender Our Humanity, We Are Still Able to Fight Back
# Article 19: Labor Department Employees Threatened With Criminal Charges for Speaking Out
# Article 20: Earth Day Sees Mobilized Resistance to Trump’s Planet-Destroying Policies
# Article 21: Critics Slam Trump’s Plan to Fill Federal Government With “Political Cronies”
# Article 22: Over a Quarter Million People Have Attended Sanders-AOC Rallies
# Article 23: Whistleblower Who Exposed DOGE Raid of NLRB Data Finds Threats Taped to His Door
# Article 24: Another DC Plane Collision Puts Trump and Musk’s FAA Cuts in the Spotlight
# Article 25: Reports: Federal Workers Fear DOGE May Be Spying on Them With AI Technology
# Article 26: Trump Administration’s Food Aid Cuts “a Death Sentence for Millions,” WFP Says
# Article 27: Protesters Demand End to Trump-Musk Power Grab in Nationwide “Hands Off” Marches
# Article 28: AI Isn’t Going to Cut Government Bureaucracy — It’s Going to Vastly Worsen It
# Article 29: Sanders: 67,000 Will Die Waiting for Social Security Benefits Under Musk Plan
# Article 30: Trump Dumping Musk Is Not Enough to Stop the Wreckage of the Federal Government
# Article 31: Elon Musk May Be Pushed Out of Trump Admin After Humiliating Wisconsin Loss
# Article 32: Musk’s Money Didn’t Win Wisconsin Supreme Court Election, Says John Nichols
# Article 33: New Forms of Resistance Are Springing Up Under the Trump-Musk Regime
# Article 34: Biden’s Rural Broadband Program May Become Casualty of Trump’s Anti-DEI Campaign
# Article 35: Thousands Protest Outside Tesla Dealerships During Global Day of Action
# Article 36: Investors From China Are Secretly Buying Stakes in Elon Musk’s SpaceX
# Article 37: Wisconsin Court Race Is Most Expensive Ever. Where Is the Money Coming From?
# Article 38: Wisconsin Election for Judge Breaks National Record for Spending on a Court Race
# Article 39: Movement in Opposition to “DOGE” Plans Day of Protests Outside Tesla Showrooms
# Article 40: Musk Offers Voters $100 Each to Support Republican in Wisconsin Judicial Race
# Article 41: House Republicans Advance Bill Backing Trump- and Musk-Led Destruction
# Article 42: Drastic DOGE-Backed Changes Put Social Security Benefits for Millions at Risk
# Article 43: Musk Pours Millions Into Wisconsin Court Race to Protect Rigged Maps for GOP
# Article 44: USPS’s Louis DeJoy Resigns as Banks “Salivate” Over Musk Goal of Privatization
# Article 45: Commerce Sec Says Only “Fraudsters” Would Miss Delayed Social Security Check
# Article 46: Trump Threatens 20-Year Sentences for Tesla Saboteurs
# Article 47: Elon Musk Donates to GOP Lawmakers After They Back His Calls to Impeach Judges
# Article 48: Millions Will Face Benefit Delays as Social Security Ends Phone Verification
# Article 49: Millions Could Die Within a Year Due to Musk-Led Foreign Aid Cuts, Report Finds
# Article 50: Calls Grow for Probe as Reports Say Musk’s Starlink Will Do Business With FAA
# Article 51: Progressives Say Chuck Schumer Has Voted to “Surrender” to Trump and Musk
# Article 52: Will Dems Draw a Line? Budget Capitulation Raises Questions Over Fights to Come.
# Article 53: Meta’s Assault on DEI Plays Right Into the Project 2025 Handbook
# Article 54: As DOGE Mauls Social Security, Profit-Hungry Private Equity Is Swooping In
# Article 55: Postmaster General Louis DeJoy Teams Up With DOGE to Gut USPS
# Article 56: Judge Orders Thousands of Fired Federal Employees to Be Reinstated Immediately
# Article 57: No Deal Yet Between Democrats and GOP as Government Funding Deadline Approaches
# Article 58: DOGE’s Cuts to HUD Will Make It Harder to Afford Housing, Exit Homelessness
# Article 59: Imagining Change Is a Crucial Step to Achieving It Under the Trump-Musk Regime
# Article 60: As Dems Mull Continuing Resolution, Sources Say Elon Musk Wants a Shutdown
# Article 61: Trump Says Tesla Dealership Attacks Should Be Called Domestic Terrorism
# Article 62: Musk Suggests Billions in Cuts to Social Security, Medicaid and Medicare
# Article 63: Musk Lawsuit Seeks to Gut Safeguards Against Executive Conflicts of Interest
# Article 64: Trump’s Cuts to USAID May Wipe Out Nearly a Tenth of Global Climate Finance
# Article 65: Nearly 3 Million Rural Americans Can’t Access Health Care and Reliable Internet
# Article 66: Women’s Day Marches Flood the Streets to Oppose Trump and Project 2025
# Article 67: The US Is Undergoing a Corporate Coup. Sudan Shows How Dangerous It Can Become.
# Article 68: Elon Musk Is Leading a Far Right Anti-Empathy Revolution
# Article 69: Hoping for DOGE Transparency, The Intercept Publishes Musk’s Government Email
# Article 70: Musk Funds Group Behind Deceptive Ads in Critical Wisconsin Supreme Court Race
# Article 71: Sanders Calls Out Trump’s “Outrageous Lie” on Social Security in Scathing Speech
# Article 72: Trump’s Speech Vowed a New “Golden Age,” But His Policies Drive Us Into the Dust
# Article 73: Sanders: 1 Percent Has Sapped $79T in Wealth From Bottom 90 Percent Since 1975
# Article 74: Elon Musk Spreads Falsehoods About Social Security, Calling It a “Ponzi Scheme”
# Article 75: Mike Johnson Claims Angry Voters Confronting GOP at Town Halls Are “Paid Actors”
# Article 76: Trump’s CFPB Drops Cases Against Companies Accused of Cheating Consumers
# Article 77: Sanders: Trump Cabinet Picks Are Nearly Irrelevant With Musk in Charge
# Article 78: AOC: Pharma Reforms Had Almost Unanimous House Support — Until Elon Musk Tweeted
# Article 79: Nearly 6 in 10 Voters Concerned Musk Is Using DOGE for His Own Financial Benefit
# Article 80: Report: Acting Leader of Social Security Administration Moves to Demolish It
# Article 81: Trump Team’s Plan to “Make America Great Again” Is to Eviscerate Public Safety
# Article 82: Staffers Resign En Masse From DOGE, Refusing to Help Musk “Dismantle” Services
# Article 83: Elon Musk Calls for Impeachment of Judges Who Oppose Trump Policies
# Article 84: Analysis Shows Nearly 4 in 10 Contracts Ended by DOGE Net No Real Savings
# Article 85: VA Employee: Musk’s Goal Is to Pave Way for Privatization of Public Services
# Article 86: Musk Waves Chainsaw, Bannon Gives Fascist-Style Salute During CPAC
# Article 87: Federal Workers Are Rallying the Labor Movement to Fight Musk’s Takeover
# Article 88: Musk’s Coup at the Treasury Has Been Ruled Illegal. Will That Stop Him?
# Article 89: J.D. Vance Met With German Neo-Nazi Party Leader Alice Weidel
# Article 90: Acting Social Security Commissioner Resigns Amid Pressure From “DOGE”
# Article 91: Washington Post Refuses to Run Ad Demanding Donald Trump Fire Elon Musk
# Article 92: Trump Openly Suggests on Social Media He’s Above the Law, Raising Alarm
# Article 93: Donald Trump Has Launched a War Against the Working Class
# Article 94: Dept. of Education Halts Thousands of Civil Rights Investigations Under Trump
# Article 95: We Are About to Learn What a Post-Truth Approach to Public Health Feels Like
# Article 96: “DOGE” Government Website Was Temporarily Alterable by Pretty Much Anyone
# Article 97: Jayapal Unveils Bill to End “Citizens United,” Slamming “Shadow President” Musk
# Article 98: German Political Leader Promises Inquiry Into Musk’s Interference in Elections
# Article 99: By Refusing to Obey Court Orders, Trump Is Provoking a Constitutional Crisis
# Article 100: How Is the Trump Family Profiting From the New Cryptocurrency Memecoin?
# Article 101: GOP Proposes $4.5T Tax Giveaway to Rich While Slashing Food Stamps, Medicaid
# Article 102: DOGE’s Illegal Takeover Pulls From Fascist Playbooks
# Article 103: White House Revoked Access to AP for Refusing to Comply With Censorship
# Article 104: Omar Slams Musk for Slashing Cancer Funding While Keeping SpaceX Contracts
# Article 105: A Third DOGE Staffer’s Racist and Misogynistic Online Footprint Comes to Light
# Article 106: Agency Tasked With Regulating Commercial Space Flight Braces for Musk’s DOGE
# Article 107: Judge Rules Trump Officials Are Defying Order to Reverse Funding Freeze
# Article 108: Trump Cuts Off South Africa Aid in Push to Further Interests of White Landowners
# Article 109: Elon Musk Reinstates DOGE Member Who Resigned Over Racist Posts
# Article 110: Russell Vought Orders Consumer Financial Protection Bureau to Stop Work
# Article 111: Federal Judge Temporarily Blocks Musk’s DOGE Team From Treasury Payment System
# Article 112: DOGE Ransacks NOAA, Raising Fears About Privatization of Climate Data
# Article 113: DOGE Member Resigns Over Social Media Posts Promoting Racism and Eugenics
# Article 114: Major Unions Sue DOGE to Block Musk Labor Department “Power Grab”
# Article 115: Trump’s Move to Abolish Ed Dept. Is Part of Broader Attack on Public Schools
# Article 116: Democrats Attempt to Oppose Musk and Trump Through Bills, Subpoenas, Filibusters
# Article 117: Senate Dems Hold Floor Overnight to Protest Russell Vought’s Nomination to OMB
# Article 118: Musk’s “Special Employee” Status Means He Needs to Avoid Conflicts of Interest
# Article 119: The Department of Education Is Reportedly the Next Target of Musk’s Team
# Article 120: Unions Sue to Halt Musk Team’s Access to Critical Treasury Payment System
# Article 121: Experts Say a Coup Is Underway as Musk Seizes Control of Government Agencies
# Article 122: Trump and Musk Threaten Shutdown of USAID in What Observers Call “Textbook Coup”
# Article 123: Musk’s DOGE Accused of Seizing Sole Control of Essential Federal Databases
# Article 124: Top Official Exits Treasury Amid Clash With Musk’s Allies Over Federal Payments
# Article 125: Trump and Musk’s Agenda Is a True Threat to Aviation Safety, Progressives Warn
# Article 126: Tesla Paid Zero Federal Income Tax in 2024, Despite $2.3 Billion in Income
# Article 127: “Musk Lackeys” Now Reportedly Control Agency Tasked With Federal HR
# Article 128: Musk Addresses German Far Right Party Days After Being Accused of “Nazi Salute”
# Article 129: Israel’s Netanyahu Says Musk “Unfairly Smeared” for Salute Embraced by Neo-Nazis
# Article 130: Milwaukee Meteorologist Fired for Calling Elon Musk’s Gesture a “Nazi Salute”
# Article 131: Report: Average Net Worth of Trump’s Top 10 Economic Advisers Tops $500 Million
# Article 132: “Citizens United” Allowed 44% of Trump’s Election to Be Funded by 10 Megadonors
# Article 133: Trump’s Vision for a “Golden Age of America”: Oligarchy Plus Ultranationalism
# Article 134: Trump Needs Public Cooperation to Enact a Fascist Vision. Here’s How We Refuse.
# Article 135: Elon Musk’s Government Efficiency Office Hit With Lawsuit on Inauguration Day
# Article 136: Elon Musk’s Foray Into UK Politics Holds a Warning for the US
# Article 137: World’s 3 Richest Men — Musk, Bezos, Zuckerberg — Will Attend Trump Inauguration
# Article 138: Elon Musk’s Influence Signifies a “New Era” in US Politics, Scholar Says
# Article 139: Trump Has Stuffed His Cabinet With Oligarchs Poised to Govern for Their Profit
# Article 140: Sanders Calls Out Musk for Billionaire Exploitation of Foreign H-1B Workers
# Article 141: Elon Musk to Host X Event Promoting Neo-Nazi AfD Party Ahead of German Elections
# Article 142: Elon Musk Op-Ed in German Newspaper Prompts Editor to Resign in Protest
# Article 143: With Trump’s Return, Combating Corporate News Disinfo Is More Urgent Than Ever
# Article 144: Trump’s Debt Ceiling Power Play Is a Prelude to the Congressional Chaos to Come
# Article 145: Elon Musk’s Threat to Primary Democrats Spurs New Urgency to Ban Super PACs
# Article 146: Congress Averts Government Shutdown After Trump and Musk’s Effort to Sink Deal
# Article 147: Musk Endorses Neo-Nazi German Party Hours After Sanders Calls Him Authoritarian
# Article 148: Government Shutdown Looms After Elon Musk Sinks Bipartisan Budget Deal
# Article 149: Republicans Consider Making Elon Musk Speaker of the House
# Article 150: President Elon? GOP Follows Billionaire Musk’s Call to Block Debt Ceiling Bill.
# Article 151: Musk Slammed Trump’s Treasury Pick. But Is Scott Bessent Really That Moderate?
# Article 152: Trump’s DOGE Team Is Asking Potential Appointees If They Can Abolish the FDIC
# Article 153: DOGE Heads Musk and Ramaswamy Signal Social Security Cuts Are Coming
# Article 154: Wealth of the World’s Billionaires Has More Than Doubled Over the Past Decade
# Article 155: Elon Musk Spent Over a Quarter of a Billion Dollars to Help Elect Trump
# Article 156: 4.3M Consumers Set to Get Checks From Agency Trump and Musk Want to “Delete”
# Article 157: AOC Becomes First Bluesky User to Reach 1 Million Followers
# Article 158: Elon Musk Targets Consumer Protection Agency for Deletion
# Article 159: AOC Lampoons Greene’s Plan to Lead “Government Efficiency” Subcommittee
# Article 160: Musk and Ramaswamy’s Plan “Could Have a Devastating Impact on Americans”
# Article 161: Trump Is Filling His Cabinet With Loyalists Prepared to Gut Federal Agencies
# Article 162: Trump Announces Elon Musk Will Lead New Department Created to Gut Regulations
# Article 163: Election 2024 Was an Open Celebration of the Oligarchy, Says David Sirota
# Article 164: The 10 Richest People’s Wealth Increased by $64 Billion the Day After Trump Win
# Article 165: Elon Musk Attempts to Delay “Lottery” Scheme Lawsuit, Move It to Federal Court
# Article 166: Philadelphia DA Sues to Block Elon Musk’s “Illegal” $1 Million Lottery to Voters
# Article 167: Sanders Warns Trump Is a Fascist Who May Let Musk Control the Presidency
# Article 168: How Do We Prepare for Election Day Threats Amid Rising Right-Wing Violence?
# Article 169: Will Justice Department Actually Rein In Elon Musk’s Blatant Vote-Buying Scheme?
# Article 170: Elon Musk’s Petition Award Amounts to “Illegal Vote Buying,” Legal Expert Warns
# Article 171: Elon Musk-Linked Dark Money Network Is Behind Fake Pro-Harris Campaign Scheme
# Article 172: The Far Right Is Creating Emblematic Narratives for People to Latch Onto
# Article 173: J.D. Vance Indicates Elon Musk’s “Efficiency” Cuts Would Include Social Security
# Article 174: Defense Contractor Musk “Jokes” Biden, Harris Should Be Assassination Targets
# Article 175: Trump Says Elon Musk Would Become Government Auditor If He’s Elected President
# Article 176: Brazilian Judge Suspends X After Musk’s Refusal to Block Far Right Accounts
# Article 177: These Billionaires Are Donating Big in 2024 Election to Advance Their Interests
# Article 178: How Elon Musk Stoked the Fire of the UK’s Far Right Anti-Immigrant Riots
# Article 179: UAW Files Labor Charges Against Trump, Musk Over Effort to “Intimidate Workers”
# Article 180: “Self Obsessed Rich Guys” — Harris Campaign Pans Musk’s Trump “Interview” on X
# Article 181: Michigan Secretary of State Investigates Elon Musk’s Pro-Trump Super PAC
# Article 182: Elon Musk Shared Fake Video of Kamala Harris. Experts Are Sounding the Alarm.
# Article 183: Billionaires Rally to Endorse Trump After Assassination Attempt
# Article 184: “Free Speech Absolutist” Elon Musk Wants to Deport Protesters Who Remove US Flag
# Article 185: US Billionaires Have Doubled Their Wealth Since 2017 Trump Tax Overhaul
# Article 186: Biden’s So-Called LNG Export Freeze Sacrifices Gulf South Communities — Again
# Article 187: Report: Trump Asked Musk to Purchase Truth Social Site Last Summer
# Article 188: World’s 5 Richest Men Have Added $14M to Their Wealth Every Hour Since 2020
# Article 189: US’s Wealthiest Collectively Held $8.5 Trillion in Untaxed Assets in 2022
# Article 190: “Free-Speech Absolutist” Musk Is Abetting Modi’s Suppression of Voices in India
# Article 191: It’s Time to Break With the ADL as a Source for News and Research on Extremism
# Article 192: Musk to Advertisers Who Left “X” Due to Antisemitic Content: “Go F*** Yourself”
# Article 193: Elon Musk’s Backing of Antisemitic Content May Cost “X” Up to $75M in Ad Revenue
# Article 194: Elon Musks’s “X” Sues Media Matters for Its Report on Antisemitic Content
# Article 195: Report Finds X Failed to Remove 98 Percent of Posts Flagged Hateful
# Article 196: Elon Musk Wants Me Fired. The People of San Francisco Want Him Taxed.
# Article 197: In Latest Attack on Journalism, Musk Removes Headlines From Posts on “X”
# Article 198: To Fight Big Tech, We Must Seize the Means of Computation
# Article 199: Warren Demands Review of Contracts With Musk Amid Actions Against Ukraine
# Article 200: Rocket-Launching Billionaires Promise a New Pie in the Sky
# Article 201: AI Won’t Overthrow Us, But It Will Optimize the Capitalist Death Machine
# Article 202: Twitter Threatens to Nix Advertisers’ Verification If They Don’t Spend More
# Article 203: Bizarre and Dangerous Utopian Ideology Has Quietly Taken Hold of Tech World
# Article 204: Twitter Refused to Pay Ex-Employees $500 Million in Severance, Lawsuit Says
# Article 205: World’s Richest Added Average of $14M Per Day to Their Wealth Over Past 6 Months
# Article 206: Twitter’s Ad Sales Have Plummeted 59 Percent in Months Since Musk’s Takeover
# Article 207: Ron DeSantis Signs Bill Shielding Elon Musk’s SpaceX From Lawsuits
# Article 208: Glitches on Twitter Interrupt Ron DeSantis’s 2024 Presidential Campaign Launch
# Article 209: Tucker Carlson Accuses Fox of Fraud, Announces Plan to Bring His Show to Twitter
# Article 210: Tesla Plans to Build Huge Factory in Mexican City Struggling With Water Scarcity
# Article 211: Musk’s SpaceX Rocket Explodes in Texas as Feds Approve New LNG Projects
# Article 212: Elon Musk Calls to “Defund” NPR After It Quits Twitter
# Article 213: Musk Calls New York Times “Propaganda” as He Removes Its Twitter Verification
# Article 214: Tesla Fired Over 30 Workers in Buffalo the Day After Union Announced Campaign
# Article 215: Tesla Workers in Buffalo Are Unionizing, With Help From Starbucks Unionists
# Article 216: Twitter’s Collapse Is Bad News for Organizers – But Another Commons Is Possible
# Article 217: White Supremacist Nick Fuentes’s Twitter Was Reinstated — Then Banned Again
# Article 218: Texas Tribe Sues Elon Musk to Protect Sacred Sites From SpaceX
# Article 219: Warren: Musk Is Using Tesla to Prop Up Twitter’s Debts and Failures
# Article 220: Free Speech Watchdogs Condemn Elon Musk for Suspending Journalists From Twitter
# Article 221: “Lay Off the Proto-Fascism”: AOC Flames Musk for Banning Accounts on Twitter
# Article 222: Musk Pledged $6B to Solve World Hunger But Gave It to His Own Foundation Instead
# Article 223: Musk Gives Right Wingers Access to Internal Twitter Systems to Spread Propaganda
# Article 224: Warren, Sanders Lost Over 100k Twitter Followers Each After Elon Musk Takeover
# Article 225: Global Coalition Calls for More Advertisers to Boycott Twitter
# Article 226: Musk’s “Hardcore” Twitter Ultimatum Backfires Spectacularly as Hundreds Resign
# Article 227: Twitter Employees Are Being Fired for Criticizing Musk on Slack
# Article 228: “What’s Elon Doing?” Jamaal Bowman Says of Twitter Issues on Election Day
# Article 229: Groups Urge Boycott of Twitter If Musk Allows Misinformation to Go Unchecked
# Article 230: Twitter Suspends Comedian Kathy Griffin After She Mocks Elon Musk
# Article 231: Employees Sue Twitter After Musk Gives Little Notice for Mass Layoffs
# Article 232: Elon Musk Hints at Trump’s Return to Twitter, Possibly in “a Few Weeks”
# Article 233: AOC Says Her Twitter Account Hasn’t Worked Properly Since She Criticized Musk
# Article 234: 40 Justice and Watchdog Groups Urge Twitter Advertisers to Hold Musk to Account
# Article 235: After Twitter Takeover, Elon Musk Tweets Far Right Conspiracy on Pelosi Attack
# Article 236: Elon Musk Completes Twitter Takeover With Help From Saudi Prince
# Article 237: Tesla Violated Workers’ Rights By Banning Pro-Union Shirts, Labor Board Rules
# Article 238: Billionaires Avoid Taxes on an Epic Scale. Here’s How.
# Article 239: 26 of US’s Richest Billionaires Paid 4.8 Percent Tax Rate in Recent Years
# Article 240: Elon Musk Says He’ll Let Trump Back on Twitter, Calling Ban “Foolish”
# Article 241: Trump Encouraged Elon Musk to Buy Twitter, Truth Social CEO Devin Nunes Says
# Article 242: Musk’s “Dangerous” Twitter Offer Makes the Case for a Wealth Tax, Warren Says
# Article 243: How Will Elon Musk’s Ownership Affect Twitter?
# Article 244: Some GOP Insiders Are Expressing Fear Over Trump’s Possible Return to Twitter
# Article 245: Musk’s $43B Offer to Buy Twitter Is Nearly Twice His Entire Pre-COVID Net Worth
# Article 246: Billionaires Would Pay Nearly 100 Times More in Taxes Under New Biden Proposal
# Article 247: Billionaires Have Gotten $1.7 Trillion Richer Over the Pandemic, Report Finds
# Article 248: Tesla May Pay $0 in Federal Taxes This Year, According to Its Financial Filings
# Article 249: California Sues Tesla Over Alleged Rampant Racism Against Black Employees
# Article 250: Elon Musk Brags About Owing Small Fraction of His $280B in Taxes
# Article 251: Elon Musk Opposes Billionaire Tax While Making a Record $36 Billion in One Day
# Article 252: Top 1 Percent in US Now Have More Wealth Than Entire Middle Class Combined
# Article 253: 7 Wealthiest Americans Have Enough Wealth to Cover a Third of $3.5T Budget Plan
# Article 254: Sanders Says No Way to $10 Billion Taxpayer Handout to Bezos’ Space Company
# Article 255: Billionaires’ Pandemic Profits Alone Could Pay for Most of Infrastructure Plan
# Article 256: Bernie Sanders Is on a Mission to Tax Billionaire CEOs
# Article 257: With Biden’s Backing, Space Force Threatens to Accelerate the Arms Race
# Article 258: The Richest 500 People in the World Added $1.8 Trillion to Their Wealth in 2020
# Article 259: New Report Shows Top Billionaires’ Wealth Skyrocketing During Pandemic
# Article 260: Billionaires Now Collectively Hold a Record-Breaking $10 Trillion in Wealth
# Article 261: Elon Musk and Rahm Emanuel’s New Transportation Scheme Is a Privatization Bonanza
# Article 262: Bridging the Gap: Why Trump Should Meet With Green Energy CEO Elon Musk for Huge Job Creation

# %% [markdown]
# # Topic Modeling

# %%
# Import Library

import pandas as pd

# Load File
corpus = pd.read_csv("elon_musk_truthout_corpus.csv", sep="\t", engine="python")

# Preview the dataset (optional)
corpus.head()
# Out:
#                                              Article
# 0  An internal document bolsters warnings that th...
# 1  Trump’s State Department has intervened on beh...
# 2  Trump’s escalation of censorship and retaliati...
# 3  Christopher Young earns up to $1 million annua...
# 4  Trump is using the baseless claim of “white ge...

# %%
#corpus['Article'][0]
#len(corpus)

# %%
# Preprocess text with CountVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Extend default stop words
custom_stop_words = set(ENGLISH_STOP_WORDS)
custom_stop_words.update(["ve", "like", "just", "really", "said"])

# CountVectorizer parameters
cv = CountVectorizer(max_df=0.90, min_df=2, stop_words=list(custom_stop_words))

# Fit and transform DTM(Document-Term Matrix)
dtm = cv.fit_transform(corpus['Article'])

# Fit LDA model to extract topics
from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=5,random_state = 42)

LDA.fit(dtm)

# Display the top 15 words per topic

for i,topic in enumerate (LDA.components_):
    print(f"THE TOP 15 WORDS FOR TOPIC #{i}")
    print([cv.get_feature_names_out()[index] for index in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['want', 'tech', 'way', 'ai', 'future', 'world', 'know', 'lot', 'going', 'things', 'right', 'space', 'kind', 'think', 'people']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['post', 'content', 'social', 'trump', 'far', 'speech', 'free', 'users', 'site', 'state', 'platform', 'company', 'media', 'right', 'twitter']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['world', 'income', 'money', 'million', 'twitter', 'year', 'percent', 'billion', 'workers', 'trump', 'wealth', 'billionaires', 'people', 'tax', 'tesla']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['right', 'company', 'cfpb', 'new', 'federal', 'president', 'know', 'party', 'house', 'republicans', 'people', 'democrats', 'spacex', 'trump', 'government']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['new', 'public', 'workers', 'employees', 'agency', 'department', 'president', 'people', 'security', 'administration', 'social', 'doge', 'federal', 'government', 'trump']

# %%
# Get topic distribution for each article

topic_result = LDA.transform(dtm)
corpus['Topic'] = topic_result.argmax(axis=1)
#corpus.head(20)

# Create a dictionary to map topic numbers to theme names
mytopic_dict = {
    0: 'Tech & AI',
    1: 'Social Media',
    2: 'Economics',
    3: 'Politics',
    4: 'DOGE/Administration'
}

# Add a new column
corpus['Topic Label'] = corpus['Topic'].map(mytopic_dict)

# Merge metadata (Publication Date)

metadata = pd.read_csv("elon_musk_truthout_metadata.csv")
corpus["Publication Date"] = metadata["Publication Date"]

# Convert 'Publication Date' to datetime using full month format
corpus["Publication Date"] = pd.to_datetime(corpus["Publication Date"], format="%B %d, %Y")

# Define U.S presidential election date
election_date = pd.to_datetime("November 5, 2024")

# Label based on election date
corpus["Election Label"] = corpus["Publication Date"].apply(
    lambda x: "Post–U.S. Election 2024" if x > election_date else "Pre–U.S. Election 2024"
)

# Save the labeled data to Excel
corpus.to_excel("elon_musk_truthout_topic_modelling.xlsx", index=False)

# Reformat date for display
corpus["Publication Date"] = corpus["Publication Date"].dt.strftime("%b %d, %Y")

# %%
corpus.head()
# Out:
#                                              Article  Topic  \
# 0  An internal document bolsters warnings that th...      4
# 1  Trump’s State Department has intervened on beh...      1
# 2  Trump’s escalation of censorship and retaliati...      1
# 3  Christopher Young earns up to $1 million annua...      4
# 4  Trump is using the baseless claim of “white ge...      4
#
#            Topic Label Publication Date           Election Label
# 0  DOGE/Administration     May 16, 2025  Post–U.S. Election 2024
# 1         Social Media     May 15, 2025  Post–U.S. Election 2024
# 2         Social Media     May 14, 2025  Post–U.S. Election 2024
# 3  DOGE/Administration     May 14, 2025  Post–U.S. Election 2024
# 4  DOGE/Administration     May 12, 2025  Post–U.S. Election 2024
